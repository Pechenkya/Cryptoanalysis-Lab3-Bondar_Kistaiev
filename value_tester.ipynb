# %% [markdown]
# # Small Exponent check

# %%
# Variant
C1 = int()
N1 = int()
C2 = int()
N2 = int()
C3 = int()
N3 = int()
C4 = int()
N4 = int()
C5 = int()
N5 = int()

e_SN = 5

# %%
# Result
M_se = int()

# %%
# Verification
Check1 = pow(M_se, e_SN, N1) == C1
Check2 = pow(M_se, e_SN, N2) == C2
Check3 = pow(M_se, e_SN, N3) == C3
Check4 = pow(M_se, e_SN, N4) == C4
Check5 = pow(M_se, e_SN, N5) == C5
if all([Check1, Check2, Check3, Check4, Check5]):
    print("Verification successful!")
else:
    print("Verification failed D:")
# Out:
# Verification successful!

# %% [markdown]
# # Meet in the middle check

# %%
# Variant
C = int(...)
N = int(...)

e_MitM = 65537

# %%
# Result
M_mitm = int(46149359335459959)
T = int(202139571)
S = int(228304429)

# %%
# Verification
Check_Calc_truth = pow(T, e_MitM, N) == ((C * pow(S, -e_MitM, N) % N))
Check_message_direct = pow(M_mitm, e_MitM, N) == C


if all([Check_Calc_truth, Check_message_direct]):
    print("Verification successful!")
else:
    print("Verification failed D:")
# Out:
# Verification successful!
